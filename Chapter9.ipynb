# %% [markdown]
# # Programming Exercise Problem 2

# %%
import random


states_and_capitals = {
    'Alabama': 'Montgomery',
    'Alaska': 'Juneau',
    'Arizona': 'Phoenix',
    'Arkansas': 'Little Rock',
    'California': 'Sacramento',
    'Colorado': 'Denver',
    'Connecticut': 'Hartford',
    'Delaware': 'Dover',
    'Florida': 'Tallahassee',
    'Georgia': 'Atlanta',
    'Hawaii': 'Honolulu',
    'Idaho': 'Boise',
    'Illinois': 'Springfield',
    'Indiana': 'Indianapolis',
    'Iowa': 'Des Moines',
    'Kansas': 'Topeka',
    'Kentucky': 'Frankfort',
    'Louisiana': 'Baton Rouge',
    'Maine': 'Augusta',
    'Maryland': 'Annapolis',
    'Massachusetts': 'Boston',
    'Michigan': 'Lansing',
    'Minnesota': 'St. Paul',
    'Mississippi': 'Jackson',
    'Missouri': 'Jefferson City',
    'Montana': 'Helena',
    'Nebraska': 'Lincoln',
    'Nevada': 'Carson City',
    'New Hampshire': 'Concord',
    'New Jersey': 'Trenton',
    'New Mexico': 'Santa Fe',
    'New York': 'Albany',
    'North Carolina': 'Raleigh',
    'North Dakota': 'Bismarck',
    'Ohio': 'Columbus',
    'Oklahoma': 'Oklahoma City',
    'Oregon': 'Salem',
    'Pennsylvania': 'Harrisburg',
    'Rhode Island': 'Providence',
    'South Carolina': 'Columbia',
    'South Dakota': 'Pierre',
    'Tennessee': 'Nashville',
    'Texas': 'Austin',
    'Utah': 'Salt Lake City',
    'Vermont': 'Montpelier',
    'Virginia': 'Richmond',
    'Washington': 'Olympia',
    'West Virginia': 'Charleston',
    'Wisconsin': 'Madison',
    'Wyoming': 'Cheyenne'
}

def quiz_user(states_and_capitals):
   
    states = list(states_and_capitals.keys())
    random.shuffle(states)
    
   
    correct_count = 0
    incorrect_count = 0
    
    
    for state in states:
        
        capital = input(f"What is the capital of {state}? ")
        
        if capital.lower() == states_and_capitals[state].lower():
            print("Correct!")
            correct_count += 1
        else:
            print(f"Incorrect! The capital of {state} is {states_and_capitals[state]}.")
            incorrect_count += 1
    
    
    print(f"\nYou got {correct_count} correct and {incorrect_count} incorrect.")


quiz_user(states_and_capitals)
# Out:
# What is the capital of Nevada? Las Vegas
# Incorrect! The capital of Nevada is Carson City.
# What is the capital of Utah? Salt Lake City
# Correct!
# What is the capital of Delaware? idk
# Incorrect! The capital of Delaware is Dover.
# What is the capital of Washington? D.C.
# Incorrect! The capital of Washington is Olympia.
# What is the capital of Arkansas? idk
# Incorrect! The capital of Arkansas is Little Rock.
# What is the capital of North Dakota? lol
# Incorrect! The capital of North Dakota is Bismarck.

# %% [markdown]
# I begin by initializing a dictionary containing U.S. states and their capitals. Using this data, I create a quiz function that iterates through a shuffled list of states, asking the user to input the capital of each state. For each state, I compare the user's input with the correct capital, incrementing counters for correct and incorrect answers, and finally display the total count of correct and incorrect responses."

# %%
Start
|
V
Initialize states_and_capitals dictionary
|
V
Define quiz_user(states_and_capitals) function
|
V
Create list of states from dictionary keys
|
V
Shuffle the list of states
|
V
Initialize correct_count = 0, incorrect_count = 0
|
V
For each state in shuffled states:
|
|--> Display "What is the capital of {state}?"
|    |
|    V
|    Get user input for capital
|    |
|    V
|    Check if capital matches states_and_capitals[state]
|    |
|    V
|    If match:
|    |--> Display "Correct!"
|    |    |
|    |    V
|    |    Increment correct_count
|    |
|    V
|    If no match:
|    |--> Display "Incorrect! The capital is {correct capital}"
|    |    |
|    |    V
|    |    Increment incorrect_count
|    |
|    V
V
Display "You got {correct_count} correct and {incorrect_count} incorrect."
|
V
End
